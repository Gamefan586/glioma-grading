# %%
import pandas as pd

# %%
# Change file path as needed

df = pd.read_csv("/Users/ronnitrana/ACSEF/glioma-grading/data/Firebrowse/Lower-Grade Glioma/mRNAseq Analyses/RSEM_genes_normalized_transposed_normalized_count_deleted.csv")
df.head()
# Out:
#               Hybridization REF  ?|100130426  ?|100133144  ?|100134869  \
# 0  TCGA-CS-4938-01B-11R-1896-07          0.0       8.7141      22.7523
# 1  TCGA-CS-4941-01A-01R-1470-07          0.0      36.4493      21.1767
# 2  TCGA-CS-4942-01A-01R-1470-07          0.0      11.8131      11.0242
# 3  TCGA-CS-4943-01A-01R-1470-07          0.0       8.6116       5.0835
# 4  TCGA-CS-4944-01A-01R-1470-07          0.0       0.0000      30.2610
#
#     ?|10357   ?|10431  ?|136542  ?|155060  ?|26823  ?|280660  ...  ZXDA|7789  \
# 0  268.5756  845.8150       0.0  182.5047   0.4196       0.0  ...    64.1913
# 1  156.6874  390.2692       0.0  325.0518   1.7253       0.0  ...   105.9351
# 2  185.1384  621.4533       0.0  131.1419   0.0000       0.0  ...   115.2249
# 3  269.8363  835.7286       0.0   83.4750   0.3261       0.0  ...    89.0183
# 4  216.3409  812.5079       0.0   80.6960   0.0000       0.0  ...    42.3654
#
#    ZXDB|158586  ZXDC|79364  ZYG11A|440590  ZYG11B|79699   ZYX|7791  \
# ...

# %%
df = df.drop("Hybridization REF", axis=1)
df.head()
# Out:
#    ?|100130426  ?|100133144  ?|100134869   ?|10357   ?|10431  ?|136542  \
# 0          0.0       8.7141      22.7523  268.5756  845.8150       0.0
# 1          0.0      36.4493      21.1767  156.6874  390.2692       0.0
# 2          0.0      11.8131      11.0242  185.1384  621.4533       0.0
# 3          0.0       8.6116       5.0835  269.8363  835.7286       0.0
# 4          0.0       0.0000      30.2610  216.3409  812.5079       0.0
#
#    ?|155060  ?|26823  ?|280660  ?|317712  ...  ZXDA|7789  ZXDB|158586  \
# 0  182.5047   0.4196       0.0       0.0  ...    64.1913     523.1802
# 1  325.0518   1.7253       0.0       0.0  ...   105.9351     467.5638
# 2  131.1419   0.0000       0.0       0.0  ...   115.2249     454.3253
# 3   83.4750   0.3261       0.0       0.0  ...    89.0183     491.0680
# 4   80.6960   0.0000       0.0       0.0  ...    42.3654     323.7927
#
#    ZXDC|79364  ZYG11A|440590  ZYG11B|79699   ZYX|7791  ZZEF1|23140  \
# ...

# %%
# Change file path as needed

df.to_csv("/Users/ronnitrana/ACSEF/glioma-grading/data/Firebrowse/Lower-Grade Glioma/mRNAseq Analyses/RSEM_genes_normalized_transposed_normalized_count_Hybridization_REF_deleted.csv", index=False)
