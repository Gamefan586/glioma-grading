# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {'Gene Mutation Dataset': 87.89, 'Transcriptomics Dataset': 98.01}
labels = list(data.keys())
values = list(data.values())

plt.figure(figsize=(5, 5))
plt.bar(labels, values, color='#8eaadc', width=0.4)

plt.ylim(75, 100)

plt.ylabel("Average Accuracy (%)")

plt.show()
