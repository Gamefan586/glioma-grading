# %%
import pandas as pd

# %%
# Change file path as needed

df = pd.read_csv("/Users/ronnitrana/ACSEF/glioma-grading/data/Firebrowse/Lower-Grade Glioma/mRNAseq Analyses/RSEM_genes_transposed.csv")
df.head()
# Out:
#                 Hybridization REF          gene_id ?|100130426  \
# 0    TCGA-CS-4938-01B-11R-1896-07        raw_count        0.00
# 1  TCGA-CS-4938-01B-11R-1896-07.1  scaled_estimate           0
# 2  TCGA-CS-4938-01B-11R-1896-07.2    transcript_id  uc011lsn.1
# 3    TCGA-CS-4941-01A-01R-1470-07        raw_count        0.00
# 4  TCGA-CS-4941-01A-01R-1470-07.1  scaled_estimate           0
#
#              ?|100133144            ?|100134869              ?|10357  \
# 0                  20.77                  54.23               640.15
# 1   6.71312141027558e-07    1.2644831502108e-06  4.8596366781048e-05
# 2  uc010unu.1,uc010uoa.1  uc002bgz.2,uc002bic.2           uc010zzl.1
# 3                 105.63                  61.37               454.08
# 4   3.53239617568874e-06   1.48766929360566e-06  3.4838177890067e-05
#
#                  ?|10431    ?|136542  \
# 0                2016.00        0.00
# 1   6.80182751091556e-05           0
# 2  uc001jiu.2,uc010qhg.1  uc011krn.1
# ...

# %%
# Change file path as needed

raw_countdf = df.query("gene_id == 'raw_count'")
raw_countdf.head()
# Out:
#                Hybridization REF    gene_id ?|100130426 ?|100133144  \
# 0   TCGA-CS-4938-01B-11R-1896-07  raw_count        0.00       20.77
# 3   TCGA-CS-4941-01A-01R-1470-07  raw_count        0.00      105.63
# 6   TCGA-CS-4942-01A-01R-1470-07  raw_count        0.00       34.14
# 9   TCGA-CS-4943-01A-01R-1470-07  raw_count        0.00       26.41
# 12  TCGA-CS-4944-01A-01R-1470-07  raw_count        0.00        0.00
#
#    ?|100134869 ?|10357  ?|10431 ?|136542 ?|155060 ?|26823  ... ZXDA|7789  \
# 0        54.23  640.15  2016.00     0.00   435.00    1.00  ...     153.0
# 3        61.37  454.08  1131.00     0.00   942.00    5.00  ...     307.0
# 6        31.86  535.05  1796.00     0.00   379.00    0.00  ...     333.0
# 9        15.59  827.53  2563.00     0.00   256.00    1.00  ...     273.0
# 12       60.00  428.95  1611.00     0.00   160.00    0.00  ...      84.0
#
#    ZXDB|158586 ZXDC|79364 ZYG11A|440590 ZYG11B|79699 ZYX|7791 ZZEF1|23140  \
# ...

# %%
# Change file path as needed

raw_countdf.to_csv("/Users/ronnitrana/ACSEF/glioma-grading/data/Firebrowse/Lower-Grade Glioma/mRNAseq Analyses/RSEM_genes_transposed_raw_count.csv", index=False)
